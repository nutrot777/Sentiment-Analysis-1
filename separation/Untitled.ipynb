# %%
import pandas as pd

# %%
liking = ['affection', 'adoration', 'fondness', 'fond', 'liking', 'like', 
        'attraction', 'attracted', 'attract', 'caring', 'care', 'tenderness', 'tender', 
         'compassion', 'sentimentality', 'sentiment', 'lust', 'sexual', 'desire', 'passion', 
         'infatuation', 'infatuated', 'infatuate', 'longing', 'lovely', 
         'excellent', 'good', 'loved', 'adore', 'best', 'perfect', 'loved', 'magnific', 
         'magnificient', 'yummy', 'love','excellent', 'wonderful', 'cheerfulness', 'cheerful', 'cheer', 'amusement', 'amuse', 
       'amused', 'amusing', 'bliss', 'blissful', 'gaiety', 'glee', 'gleeing', 
       'jolliness', 'jolly', 'joviality', 'joy', 'delight', 'enjoyment', 
       'glad', 'gladness', 'happiness', 'happy', 'jubilation', 'elation', 'elating', 
       'satisfication', 'satisfying', 'satisfied', 'ecstasy', 'euphoria', 'zest', 
       'enthusiasm','enthusiatic', 'zeal', 'excitement', 'exciting', 'thrill', 'thrilling', 
       'exhilaration', 'exhilarating', 'content', 'contentment', 'pleasure', 'pride', 'triumph', 'optimism', 
       'optimistic', 'eager', 'eagerness', 'hope', 'enthrallment', 'rapture', 'relief', 'beautiful', 
       'enjoy', 'super', 'excellent', 'fantastic', 'superb', 'free', 'wonderful', 
       'happy', 'brillant', 'perfect', 'success', 'appreciate', 'delightful', 'delight', 
       'divine', 'gracious', 'winning', 'lmfao', 'win','surprise','surprising', 'amazement', 'amazed', 'amazing', 'astonishment', 'astonishing', 'astonished', 
           'astonish', 'awesome', 'great', 'super', 'outsanding', 'fascinating', 'fascinated']

liking = list(dict.fromkeys(liking))
l = pd.DataFrame({'liking':liking})

trust = ['trust', 'comfort', 'comfortable', 'encourage', 'encouraging', 
        'marvelous', 'marvel', 'kudos', 'thankful', 'perfect', 'perfection']
trust = list(dict.fromkeys(trust))
t = pd.DataFrame({'trust':trust})




anger = ['irritability', 'irritating', 'irritated', 'irritation', 'aggravation', 'agitation', 'agitated', 
        'annoyed', 'annoyance', 'annoying', 'grumpy', 'crosspatch', 'exasperation', 'frustration', 'rage', 'raging', 
        'annoy', 'anger', 'outrage', 'outraged', 'fury', 'wrath', 'hostility', 'hostile', 
        'ferocity', 'bitter', 'bitterness', 'hate', 'hatred','scorn', 'spite', 'vengefulness', 'dislike', 'disliking', 
        'disliked', 'resent', 'resenting', 'resentment', 'disgusting', 'disgust', 'revulsion', 'contempt', 
        'loathing', 'loathe', 'envy', 'jealous', 'jealousy', 'torment', 'tormenting', 'idiot', 'suck', 'sucker', 
        'loser', 'dumbass', 'hate']
anger = list(dict.fromkeys(anger))
a = pd.DataFrame({'anger':anger})


sadness = ['sad', 'suffer', 'suffering', 'pain', 'agony', 'anguish', 'hurt', 
          'sadness', 'depression', 'depress', 'despair', 'gloom', 'glooming', 
          'glumness', 'unhappy', 'unhappiness', 'grief', 'sorrow', 'woe', 'misery', 'melancholy', 'disappointment', 
          'disappointing', 'disappoint', 'dismay', 'displeasure', 'shame', 'shaming', 
          'shameful', 'guilt', 'regret', 'regreting', 'regretful', 'remorse', 
          'remorseful', 'neglect', 'alienation', 'defeatism', 'defeat', 'defeating', 
          'dejection', 'dejected', 'dejecting', 'embarrassing', 'embarrassment', 
          'homesickness', 'homesick', 'humiliating', 'humilating', 'insecurity', 'insecure', 
          'insult', 'insulting', 'isolation', 'isolating', 'isolate', 'loneliness', 'lonely', 'rejection', 
          'reject', 'rejecting', 'sympathy', 'pity', 'loser', 'unhealthy', 'ruin', 
          'ruining', 'sick']
sadness = list(dict.fromkeys(sadness))
sa = pd.DataFrame({'sadness':sadness})


fear = ['horror', 'alarm', 'alarming', 'shocking', 'shock', 'fear', 'fearful', 
       'terror', 'panic', 'hysteria', 'mortification', 'nervous', 'nervousness', 'anxious', 'anxiety', 
       'suspense', 'uneasy', 'uneasiness', 'suspenseful', 'apprehension', 'apprehen', 
       'worry', 'worrying', 'distress', 'distressful', 'dread', 'dreadful', 'danger', 
       'dangerous', 'fraud', 'hell', 'painfull', 'scam', 'stress', 'stressing', 'stressful']
fear = list(dict.fromkeys(fear))
f = pd.DataFrame({'fear':fear})

# %%
sentiments = pd.concat([l,t,a, sa,f], axis=1)

# %%
sentiments.head(10)
# Out:
#        liking        trust         anger     sadness      fear
# 0   affection        trust  irritability         sad    horror
# 1   adoration      comfort    irritating      suffer     alarm
# 2    fondness  comfortable     irritated   suffering  alarming
# 3        fond    encourage    irritation        pain  shocking
# 4      liking  encouraging   aggravation       agony     shock
# 5        like    marvelous     agitation     anguish      fear
# 6  attraction       marvel      agitated        hurt   fearful
# 7   attracted        kudos       annoyed     sadness    terror
# 8     attract     thankful     annoyance  depression     panic
# 9      caring      perfect      annoying     depress  hysteria

# %%
sentiments.to_csv('sentiments_comparison.csv', index=None)
