# %%
import re
import numpy as np
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
import string 
import nltk 
nltk.download('vader_lexicon')
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer
import warnings 
from nltk.corpus import stopwords
from wordcloud import WordCloud, STOPWORDS
import csv
warnings.filterwarnings("ignore", category=DeprecationWarning )

# %matplotlib inline
# Out:
# [nltk_data] Error loading vader_lexicon: <urlopen error [Errno -3]
# [nltk_data]     Temporary failure in name resolution>

# %%
features = pd.read_csv('sentiments_comparison.csv')
features.head(5)
# Out:
#       liking        trust         anger    sadness      fear
# 0  affection        trust  irritability        sad    horror
# 1  adoration      comfort    irritating     suffer     alarm
# 2   fondness  comfortable     irritated  suffering  alarming
# 3       fond    encourage    irritation       pain  shocking
# 4     liking  encouraging   aggravation      agony     shock

# %%
dataset = pd.read_csv('../../mHealth_apple/A46.csv')

# %%
dataset.count()
# Out:
# date                 1164
# isEdited             1164
# rating               1164
# userName             1164
# title                1164
# developerResponse     488
# review               1164
# dtype: int64

# %%
#dataset = dataset.drop(columns=['reviewId','userImage', 'thumbsUpCount', 'reviewCreatedVersion', 'at', 'replyContent', 'repliedAt'])
dataset = dataset.drop(columns=['isEdited', 'title', 'date', 'developerResponse'])

# %%
dataset.dropna()
# Out:
#       rating              userName  \
# 0          4  Whoreadsnamesanyways
# 1          4              Ragdoll9
# 2          1            scootage81
# 3          5       lazarbeamislife
# 4          5              Pringlle
# ...      ...                   ...
# 1159       2                Araiaf
# 1160       4            50fabfifty
# 1161       1             Mystic108
# 1162       3           David Celis
# 1163       1            candinimio
#
#                                                  review
# 0     I’ve NEVER been good at drinking my water, to ...
# 1     I just got this the other day and have improve...
# 2     I long ago gave up on using the sensor stick b...
# 3     First of all - I love my bottle! I bring it ev...
# 4     I bought the black bottle at a discount store ...
# ...                                                 ...
# 1159  Concept is good, however the following issues ...
# 1160  This is a great app to help remind me to drink...
# 1161  I have held off for two weeks on writing this ...
# 1162  Ever since the latest update, Hidrate won't sy...
# 1163  I finally received my Hidrate Spark yesterday ...
#
# [1164 rows x 3 columns]

# %%
#data cleaning 
def clean_text(text):
    text = str(text)
    #filter to allow only aphabets
    text = re.sub(r'[^a-zA-z\']', ' ', text)
    #remove unicode characters 
    text = re.sub(r'[^\x00-\x7F]+', ' ', text)
    #remove special characters, numbers, punctuations
   # text = re.sub(r'[^a-zA-Z#\']', ' ', text)
    #removing shortwords
    text = ' '.join([w for w in text.split() if len(w)>3])
    #lower case 
    text = text.lower()
    
    return text

# %%
#dataset['clean_review'] = dataset.content.apply(lambda x: np.vectorize(clean_text)(x))
dataset['clean_review'] = dataset.review.apply(lambda x: np.vectorize(clean_text)(x))

# %%
stopwords = set(STOPWORDS)
stopwords.update(['this', 'used', 'really', " ' ", "weight"])

words = " ".join(str(text) for text in dataset.clean_review)
wordcloud = WordCloud(stopwords=stopwords, width=800, height=500, random_state=30, max_font_size=110).generate(words)

plt.figure(figsize=(10,7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
#Extracting words
def extract(x):
    words = []
    #Loop over the words in the content 
    for i in x: 
        word = re.findall(r"\b\w{4,225}\b",i)
        words.append(word)
        
    return words

# %%
#allWords = extract(dataset['clean_review'][dataset['score']>3])
#positive_w = extract(dataset['clean_review'][dataset['score']>3])
#negative_w = extract(dataset['clean_review'][dataset['score']<3])
#neutral_w = extract(dataset['clean_review'][dataset['rating']==3])
#allWords = sum(allWords, [])
#allWords

positive_w = extract(dataset['clean_review'][dataset['rating']>3])
negative_w = extract(dataset['clean_review'][dataset['rating']<3])

positive_w = sum(positive_w, [])
negative_w = sum(negative_w, [])
#neutral_w = sum(neutral_w, [])
allWords = []
allWords.append(positive_w)
allWords.append(negative_w)
allWords = sum(allWords, [])

# %%
len(allWords)
# Out:
# 26758

# %%
word_freq = nltk.FreqDist(allWords)
dict_filter1 = lambda word_freq, stopwords: dict((w, word_freq[w]) for w in word_freq if w not in stopwords)
relevant_w = dict_filter1(word_freq, stopwords)

# %%
len(relevant_w)
# Out:
# 2923

# %%
relevant_words = pd.DataFrame({'Word_freq': list(relevant_w.keys()),
                              'Word_Count':list(relevant_w.values()),
                             })

# %%
#Extracting real-relevant sentiments
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sid = SentimentIntensityAnalyzer()

texts = []
#neg_word_list = []
#neu_word_list = [] 
for word1 in relevant_words['Word_freq']:
    if(sid.polarity_scores(word1)['compound'])>0.5 or (sid.polarity_scores(word1)['compound'])<-0.5:
        texts.append(word1)

len(texts)
# Out:
# 88

# %%
liking = []
trust = []
anger = []
sadness = []
fear = []
#lemma = WordNetLemmatizer()

# %%
texts
# Out:
# ['great',
#  'love',
#  'excellent',
#  'ideal',
#  'best',
#  'awesome',
#  'perfect',
#  'amazing',
#  'super',
#  'loved',
#  'stupid',
#  'free',
#  'hate',
#  'brilliant',
#  'superb',
#  'wonderful',
#  'fantastic',
#  'horrible',
#  'kind',
#  'happy',
#  'perfectly',
#  'gain',
#  'dumb',
#  'worst',
#  'encouraging',
#  'loving',
#  'dead',
#  'lovely',
#  'bullshit',
#  'unhealthy',
#  'negative',
#  'beautiful',
#  'pleasing',
#  'honest',
#  'hated',
#  'beauty',
#  'idiot',
#  'fabulous',
#  'lmao',
#  'frustrated',
#  'sick',
#  'trust',
#  'gorgeous',
#  'hurt',
#  'sobs',
#  'appreciated',
#  'cheer',
#  'disturbing',
#  'irritation',
#  'appreciation',
#  'inspiration',
#  'loves',
#  'friendliest',
#  'beautifully',
#  'loser',
#  'failed',
#  'failure',
#  'brilliantly',
#  'congrats',
#  'congratulations',
#  'impressive',
#  'comfortable',
#  'prize',
#  'lovers',
#  'kudos',
#  'hahaha',
#  'excels',
#  'insanity',
#  'dumbass',
#  'superior',
#  'fail',
#  'ugly',
#  'horribly',
#  'peace',
#  'negativity']

# %%
from itertools import zip_longest

l = [] #liking synonyms
t = [] #trust synonyms
a = [] #anger synonyms
sa = [] #sad synonyms
f = [] #fear synonyms
 
for w in features.liking.values:
    for syn in wordnet.synsets(str(w)):
        for lemma in syn.lemmas():
            l.append(lemma.name())
for txt in texts: 
    if txt in set(l):
        liking.append(txt)
liking = list(dict.fromkeys(liking))
#################################################

for w1 in features.trust.values:
    for syn_t in wordnet.synsets(str(w1)):
        for lemma1 in syn_t.lemmas():
            t.append(lemma1.name())
for txt in texts:
    if txt in set(t):
        trust.append(txt)
trust = list(dict.fromkeys(trust))
################################################


for w4 in features.anger.values:
    for syn_a in wordnet.synsets(str(w4)):
        for lemma4 in syn_a.lemmas():
            a.append(lemma4.name())
            
for txt in texts: 
    if txt in set(a):
        anger.append(txt)
anger = list(dict.fromkeys(anger))
######################################################

for w5 in features.sadness.values:
    for syn_sa in wordnet.synsets(str(w5)):
        for lemma5 in syn_sa.lemmas():
            sa.append(lemma5.name())
for txt in texts:
    if txt in set(sa):
        sadness.append(txt)
sadness = list(dict.fromkeys(sadness))
        
########################################################
for w6 in features.fear.values:
    for syn_f in wordnet.synsets(str(w6)):
        for lemma6 in syn_f.lemmas():
            f.append(lemma6.name())
            
for txt in texts:
    if txt in set(f):
        fear.append(txt)
fear = list(dict.fromkeys(fear))

# %%
for duplicate in liking:
    if duplicate in trust:
        trust.remove(duplicate)
        
for duplicate in trust:
    if duplicate in anger:
        anger.remove(duplicate)
        
for duplicate in anger:
    if duplicate in sadness:
        sadness.remove(duplicate)


for duplicate in sadness:
    if duplicate in fear:
        fear.remove(duplicate)

# %%
print(liking, " ", len(liking))
print(" ")
print(trust, ' ', len(trust))
print(" ")

print(" ")
print(anger, " ", len(anger))
print(" ")
print(sadness, " ", len(sadness))
print(" ")
print(fear, " ", len(fear))
# Out:
# ['great', 'love', 'excellent', 'best', 'awesome', 'perfect', 'amazing', 'super', 'loved', 'free', 'brilliant', 'superb', 'wonderful', 'fantastic', 'happy', 'gain', 'lovely', 'beautiful', 'honest', 'trust', 'cheer', 'prize']   22
#
# ['encouraging', 'congratulations', 'comfortable', 'kudos']   4
#
#
# ['hate', 'idiot', 'hurt', 'irritation', 'loser', 'failure', 'dumbass']   7
#
# ['unhealthy', 'sick', 'fail']   3
#
# ['hurt', 'disturbing']   2

# %%
def percent(li, tr, an, sa, fea):
    total = len(texts)
    
    print("Liking: ", (len(li)/total)*100)
    print(" ")
    print("Trust: ", (len(tr)/total)*100)
    print(" ")
    print("Anger: ", (len(an)/total)*100)
    print(" ")
    print("Sadness: ", (len(sa)/total)*100)
    print(" ")
    print("Fear: ", (len(fea)/total)*100)

# %%
liking_sentiment = pd.DataFrame({'liking':liking})
trust_sentiment = pd.DataFrame({'trust':trust})
anger_sentiment = pd.DataFrame({'anger':anger})
sadness_sentiment = pd.DataFrame({'sadness':sadness})
fear_sentiment = pd.DataFrame({'fear':fear})


sentiments = pd.concat([liking_sentiment, trust_sentiment, anger_sentiment, sadness_sentiment, fear_sentiment], axis = 1)

# %%
sentiments.head(10)
# Out:
#       liking            trust       anger    sadness        fear
# 0      great      encouraging        hate  unhealthy  disturbing
# 1       love  congratulations       idiot       sick        hurt
# 2  excellent      comfortable        hurt       fail         NaN
# 3       best            kudos  irritation        NaN         NaN
# 4    awesome              NaN       loser        NaN         NaN
# 5    perfect              NaN     failure        NaN         NaN
# 6    amazing              NaN     dumbass        NaN         NaN
# 7      super              NaN         NaN        NaN         NaN
# 8      loved              NaN         NaN        NaN         NaN
# 9       free              NaN         NaN        NaN         NaN
